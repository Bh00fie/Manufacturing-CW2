# %%
#Variables
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

total_packs_required_Li = 5000
total_packs_required_Al = 5000
n_lines_Li = 1
n_lines_Al = 1
n_conveyer = 3
n_robot = 1

# %%
#Q2 i - Li
cells_per_pack_Li = 30
cells_per_pack_Al = 40

operational_hours_per_day = 20
operational_days_per_week = 7
picking_time_per_cell = 9  # seconds
bin_replacement_time = 15 # Seconds
defect_rate_Li = 1 / 4000
defect_rate_Al = 1 / 2000
n_lines = n_lines_Li+n_lines_Al 
number_of_components_per_line = n_conveyer+n_robot
probability_of_failure = 0.01
probability_of_failure_per_pack = number_of_components_per_line*probability_of_failure
average_downtime_per_failure = 30 * 60  # converting minutes to seconds
#Cost Analysis
cost_per_conveyer = 10*1e3
cost_per_robot = 125*1e3
conveyer_use_per_hour = 10 
robot_use_per_hour = 10
conveyer_repair_per_hour = 1000
robot_repair_per_hour = 1000
current_cost = 155*1e3

# %%
# Effective cells needed considering defects
effective_cells_per_pack_Li = cells_per_pack_Li / (1 - defect_rate_Li)
print(f'The total number of packs required including the rate of defect to meet the annual demand is {effective_cells_per_pack_Li}')
# Total effective cells needed
total_effective_cells_Li = effective_cells_per_pack_Li * total_packs_required_Li
print(f'If this value of {effective_cells_per_pack_Li} is converted in the number of cell that needs to manufactured, this is {total_effective_cells_Li}')
print("----------")

# Actual Time
#Total Time per pack:
time_per_pack_Li = effective_cells_per_pack_Li*picking_time_per_cell
print(f'Time per pack is {time_per_pack_Li} s')
#Downtime per pack
downtime_per_second_Li = probability_of_failure*average_downtime_per_failure
print(f'Every hour the machine is going to fail {downtime_per_second_Li}')
time_per_pack_with_bin_Li = time_per_pack_Li+downtime_per_second_Li*number_of_components_per_line+bin_replacement_time
print(f'Thus the real time per pack is {time_per_pack_with_bin_Li}')
operational_time_for_packs_Li = total_packs_required_Li*time_per_pack_with_bin_Li
# print(f'\n\n {operational_time_for_packs_Li}')
operational_time_hour_Li = (operational_time_for_packs_Li/3600)/n_lines_Li
print(f'Thus the total actual operational hour is {operational_time_hour_Li} hours')
production_rate_actual_hour_Li = total_packs_required_Li/operational_time_hour_Li
print(f'The actual production per hour is {production_rate_actual_hour_Li} unit per hour')
print("----------")
# Number of failures expected over the production of 10,000 packs
expected_failures_Li = total_packs_required_Li * probability_of_failure_per_pack
print(f'As the failure is {probability_of_failure_per_pack}, the toal number of packs that are going to fail are {expected_failures_Li}')
# Total downtime due to failures in hours
total_downtime_hours_Li = ((expected_failures_Li * average_downtime_per_failure)+(expected_failures_Li*bin_replacement_time)) / 3600
# total_downtime_hours_Li = ((expected_failures_Li * average_downtime_per_failure)) / 3600
print(f'Thus, as the downtime per falure is {average_downtime_per_failure/60} minutes, the production line will be stopped for {total_downtime_hours_Li} hours')
print("----------")
# Ideal Time
time_per_pack_ideal_Li = cells_per_pack_Li*picking_time_per_cell+bin_replacement_time
print(f'The ideal time without any losses per pack is {time_per_pack_ideal_Li} seconds')
prodution_rate_ideal_hour_Li = (3600/time_per_pack_ideal_Li)*n_lines_Li
print(f'The ideal production rate is {prodution_rate_ideal_hour_Li} unites per hour')
print("----------")
# Efficiency
Efficiency_Li = production_rate_actual_hour_Li/prodution_rate_ideal_hour_Li
print(f'The efficiency is: {Efficiency_Li*100} % ')
print("----------")

#### Aluminium
print('\nALUMINIUM BATTERIES')
# Effective cells needed considering defects
effective_cells_per_pack_Al = cells_per_pack_Al / (1 - defect_rate_Al)
print(f'The total number of packs required including the rate of defect to meet the annual demand is {effective_cells_per_pack_Al}')
# Total effective cells needed
total_effective_cells_Al = effective_cells_per_pack_Al * total_packs_required_Al
print(f'If this value of {effective_cells_per_pack_Al} is converted in the number of cell that needs to manufactured, this is {total_effective_cells_Al}')
print("----------")

# Actual Time
#Total Time per pack:
time_per_pack_Al = effective_cells_per_pack_Al*picking_time_per_cell
print(f'Time per pack is {time_per_pack_Al} s')
#Downtime per pack
downtime_per_second_Al = probability_of_failure*average_downtime_per_failure
print(f'Every hour the machine is going to fail {downtime_per_second_Al}')
time_per_pack_with_bin_Al = time_per_pack_Al+downtime_per_second_Al*number_of_components_per_line+bin_replacement_time
print(f'Thus the real time per pack is {time_per_pack_with_bin_Al}')
operational_time_for_packs_Al = total_packs_required_Al*time_per_pack_with_bin_Al
operational_time_hour_Al = (operational_time_for_packs_Al/3600)/n_lines_Al
print(f'Thus the total actual operational hour is {operational_time_hour_Al} hours')
production_rate_actual_hour_Al = total_packs_required_Al/operational_time_hour_Al
print(f'The actual production per hour is {production_rate_actual_hour_Al} unit per hour')
print("----------")
# Number of failures expected over the production of 10,000 packs
expected_failures_Al = total_packs_required_Al * probability_of_failure_per_pack
print(f'As the failure is {probability_of_failure_per_pack}, the toal number of packs that are going to fail are {expected_failures_Al}')
# Total downtime due to failures in hours
total_downtime_hours_Al = ((expected_failures_Al * average_downtime_per_failure)+(expected_failures_Al*bin_replacement_time)) / 3600
# total_downtime_hours_Al = ((expected_failures_Al * average_downtime_per_failure)) / 3600
print(f'Thus, as the downtime per falure is {average_downtime_per_failure/60} minutes, the production line will be stopped for {total_downtime_hours_Al} hours')
print("----------")
# Ideal Time
time_per_pack_ideal_Al = cells_per_pack_Al*picking_time_per_cell+bin_replacement_time
print(f'The ideal time without any losses per pack is {time_per_pack_ideal_Al} seconds')
prodution_rate_ideal_hour_Al = (3600/time_per_pack_ideal_Al)*n_lines_Al
print(f'The ideal production rate is {prodution_rate_ideal_hour_Al} unites per hour')
print("----------")
# Efficiency
Efficiency_Al = production_rate_actual_hour_Al/prodution_rate_ideal_hour_Al
print(f'The efficiency is: {Efficiency_Al*100} % ')
print("----------")
# Out:
# The total number of packs required including the rate of defect to meet the annual demand is 30.007501875468865
# If this value of 30.007501875468865 is converted in the number of cell that needs to manufactured, this is 150037.50937734434
# ----------
# Time per pack is 270.0675168792198 s
# Every hour the machine is going to fail 18.0
# Thus the real time per pack is 357.0675168792198
# Thus the total actual operational hour is 495.92710677669413 hours
# The actual production per hour is 10.08212685226621 unit per hour
# ----------
# As the failure is 0.04, the toal number of packs that are going to fail are 200.0
# Thus, as the downtime per falure is 30.0 minutes, the production line will be stopped for 100.83333333333333 hours
# ----------
# The ideal time without any losses per pack is 285 seconds
# The ideal production rate is 12.631578947368421 unites per hour
# ----------
# The efficiency is: 79.81683758044082 %
# ----------
#
# ALUMINIUM BATTERIES
# The total number of packs required including the rate of defect to meet the annual demand is 40.0200100050025
# If this value of 40.0200100050025 is converted in the number of cell that needs to manufactured, this is 200100.0500250125
# ----------
# Time per pack is 360.1800900450225 s
# Every hour the machine is going to fail 18.0
# Thus the real time per pack is 447.1800900450225
# Thus the total actual operational hour is 621.0834583958646 hours
# The actual production per hour is 8.050447862375869 unit per hour
# ----------
# As the failure is 0.04, the toal number of packs that are going to fail are 200.0
# Thus, as the downtime per falure is 30.0 minutes, the production line will be stopped for 100.83333333333333 hours
# ----------
# The ideal time without any losses per pack is 375 seconds
# The ideal production rate is 9.6 unites per hour
# ----------
# The efficiency is: 83.85883189974864 %
# ----------

# %%
print("COST ANALYSIS")
#####COST
# Purchase Cost
Total_cost_conveyer = n_conveyer*cost_per_conveyer
Total_cost_robot = n_robot*cost_per_robot
Total_purchase_cost_Li = ((Total_cost_conveyer+Total_cost_robot)*(n_lines_Li))-(current_cost*(n_lines_Li/n_lines))
Total_purchase_cost_Li = ((Total_cost_conveyer+Total_cost_robot)*(n_lines_Li))-(current_cost*(n_lines_Li/n_lines))
Total_purchase_cost_Al = ((Total_cost_conveyer+Total_cost_robot)*(n_lines_Al))-(current_cost*(n_lines_Al/n_lines))
Total_purchase_cost = Total_purchase_cost_Li + Total_purchase_cost_Al
print(f'Conveyer cost in pound is {Total_cost_conveyer}, robot is {Total_cost_robot}, thus the total purchase cost is {Total_purchase_cost}')

###### LITHIUM
print(f'\nLITHIUM COST LINE')
# Operational Cost
# Conveyer Operational Cost
conveyer_use_cost_Li = n_conveyer*conveyer_use_per_hour*(operational_time_hour_Li-total_downtime_hours_Li)
print(f'Total Conveyer Cost for use is {conveyer_use_cost_Li} £')
conveyer_repair_cost_Li = n_conveyer*conveyer_repair_per_hour*(total_downtime_hours_Li/(n_conveyer/number_of_components_per_line))
print(f'Conveyer Repair cost is: {conveyer_repair_cost_Li} £')
#Robot Operational Cost
robot_use_cost_Li = n_robot*robot_use_per_hour*(operational_time_hour_Li-total_downtime_hours_Li)
print(f'Total Robot Cost for use is {robot_use_cost_Li} £')
robot_repair_cost_Li = n_robot*robot_repair_per_hour*(total_downtime_hours_Li/(n_robot/number_of_components_per_line))
print(f'Robot Repair cost is: {robot_repair_cost_Li} £')
total_operational_cost_Li = (conveyer_use_cost_Li + conveyer_repair_cost_Li + robot_use_cost_Li + robot_repair_cost_Li)*n_lines_Li
print(f'Total Operational Cost of all Lithium Line is: {total_operational_cost_Li} £')
total_Li_cost = (Total_purchase_cost_Li+total_operational_cost_Li)
total_Li_cost_hour = (total_operational_cost_Li/operational_time_hour_Li)
print(f'Total Operational cost per hour for Li is: {total_Li_cost_hour}')
print(f'The Total Cost of Li is: {total_Li_cost}')

#UNIT COST LI
# capra_Li = (total_Li_cost-(current_cost*(n_lines_Li/n_lines)))/operational_time_hour_Li
capra_Li = (total_Li_cost)/operational_time_hour_Li
print(capra_Li)
print(f'\nUnit Processing Cost for Li battery is {(capra_Li)/production_rate_actual_hour_Li}')

###### ALUMINIUM
print(f'\nALUMINIUM COST LINE')
# Operational Cost
# Conveyer Operational Cost
conveyer_use_cost_Al = n_conveyer*conveyer_use_per_hour*(operational_time_hour_Al-total_downtime_hours_Al)
print(f'Total Conveyer Cost for use is {conveyer_use_cost_Al} £')
conveyer_repair_cost_Al = n_conveyer*conveyer_repair_per_hour*(total_downtime_hours_Al/(number_of_components_per_line))
print(f'Conveyer Repair cost is: {conveyer_repair_cost_Al} £')
#Robot Operational Cost
robot_use_cost_Al = n_robot*robot_use_per_hour*(operational_time_hour_Al-total_downtime_hours_Al)
print(f'Total Robot Cost for use is {robot_use_cost_Al} £')
robot_repair_cost_Al = n_robot*robot_repair_per_hour*(total_downtime_hours_Al/number_of_components_per_line)
print(f'Robot Repair cost is: {robot_repair_cost_Al} £')
total_operational_cost_Al = (conveyer_use_cost_Al + conveyer_repair_cost_Al + robot_use_cost_Al + robot_repair_cost_Al)*n_lines_Al
print(f'Total Operational Cost of all Aluminium Line is: {total_operational_cost_Al} £')
total_Al_cost = (Total_purchase_cost_Al+total_operational_cost_Al)
total_Al_cost_hour = (total_operational_cost_Al/operational_time_hour_Al)
print(f'Total Operational cost per hour for Al is: {total_Al_cost_hour}')
print(f'The Total Cost of Al is: {total_Al_cost}')

#UNIT COST Al
# capra_Al = (total_Al_cost-(current_cost*(n_lines_Al/n_lines)))/operational_time_hour_Al
capra_Al = (total_Al_cost)/operational_time_hour_Al
print(capra_Al)
print(f'\nUnit Processing Cost for Li battery is {(capra_Al)/production_rate_actual_hour_Al}')
# Out:
# COST ANALYSIS
# Conveyer cost in pound is 30000.0, robot is 125000.0, thus the total purchase cost is 155000.0
#
# LITHIUM COST LINE
# Total Conveyer Cost for use is 11852.813203300824 £
# Conveyer Repair cost is: 403333.3333333333 £
# Total Robot Cost for use is 3950.937734433608 £
# Robot Repair cost is: 403333.3333333333 £
# Total Operational Cost of all Lithium Line is: 822470.417604401 £
# Total Operational cost per hour for Li is: 1658.450216504787
# The Total Cost of Li is: 899970.417604401
# 1814.7231827149133
#
# Unit Processing Cost for Li battery is 179.9940835208802
#
# ALUMINIUM COST LINE
# Total Conveyer Cost for use is 15607.503751875936 £
# Conveyer Repair cost is: 75625.0 £
# Total Robot Cost for use is 5202.5012506253115 £
# Robot Repair cost is: 25208.333333333332 £
# Total Operational Cost of all Aluminium Line is: 121643.33833583457 £
# Total Operational cost per hour for Al is: 195.8566706155968
# The Total Cost of Al is: 199143.33833583456
# 320.6386124824228
#
# Unit Processing Cost for Li battery is 39.82866766716692

# %%
# # Graph
# Total operational cost
total_operational_cost = total_operational_cost_Li/operational_time_hour_Li + total_operational_cost_Al/operational_time_hour_Al
print(f'\nTotal Operational Cost per hour of every line is: {total_operational_cost} £')

# Calculate cumulative costs over time
time_hours_Li = np.arange(0, operational_time_hour_Li + 1)
time_hours_Al = np.arange(operational_time_hour_Li, operational_time_hour_Al + 1)

# THIS ONE FOR JUST LITHIUM ON ITS OWN
# cost_accumulated_Li = total_operational_cost * time_hours_Li 

cost_accumulated_Li = total_operational_cost * time_hours_Li + Total_purchase_cost
cost_accumulated_Al = cost_accumulated_Li[-1] + total_Al_cost_hour * (time_hours_Al - operational_time_hour_Li)

# THIS ONE FOR JUST LITHIUM ON ITS OWN
# time_hours_combined = time_hours_Li
# cost_accumulated_combined = cost_accumulated_Li

# Combine arrays for plotting
time_hours_combined = np.concatenate([time_hours_Li, time_hours_Al[1:]])
cost_accumulated_combined = np.concatenate([cost_accumulated_Li, cost_accumulated_Al[1:]])

# Plotting the cumulative cost graph
plt.figure(figsize=(10, 5))

# THIS ONE FOR JUST LITHIUM ON ITS OWN
# plt.plot(time_hours_Li, cost_accumulated_Li, label='Cumulative Operational Cost')

plt.plot(time_hours_combined, cost_accumulated_combined, label='Cumulative Operational Cost')
plt.title('Cumulative Operational Cost Over Time')
plt.xlabel('Operational Time (Hours)')
plt.ylabel('Cumulative Cost (£)')
plt.axvline(x=operational_time_hour_Li, color='r', linestyle='--', label='Max Li Operational Hours')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Total Operational Cost per hour of every line is: 1854.3068871203839 £

# %%
# Save coordinates in Excel
# Your DataFrame data setup
df = pd.DataFrame({
    "Time (Hours)": time_hours_combined,
    "Cumulative Cost (£)": cost_accumulated_combined
})

# Set the path to where you want to save the Excel file on your local machine
file_path = fr"C:\Users\abhin\OneDrive - University of Southampton\1 - University of Southampton\Part 4 - University of Southampton\Manufacturing\2 - CW\Q2\Manufacturing-CW2\EXCEL\Cumulative_Operational_Cost_Over_Time_{total_packs_required_Li}_{n_lines_Li}_{n_lines_Al}_{n_conveyer}_{n_robot}.xlsx"

# Save the DataFrame to an Excel file at the specified path
df.to_excel(file_path, index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the first Excel file
file_path_1 = r"C:\Users\abhin\OneDrive - University of Southampton\1 - University of Southampton\Part 4 - University of Southampton\Manufacturing\2 - CW\Q2\Manufacturing-CW2\EXCEL\Cumulative_Operational_Cost_Over_Time_2500_2_2_2_1.xlsx"
df1 = pd.read_excel(file_path_1)

# Load the data from the second Excel file
file_path_2 = r"C:\Users\abhin\OneDrive - University of Southampton\1 - University of Southampton\Part 4 - University of Southampton\Manufacturing\2 - CW\Q2\Manufacturing-CW2\EXCEL\Cumulative_Operational_Cost_Over_Time_5000_1_3_1.xlsx"
df2 = pd.read_excel(file_path_2)

file_path_3 = r"C:\Users\abhin\OneDrive - University of Southampton\1 - University of Southampton\Part 4 - University of Southampton\Manufacturing\2 - CW\Q2\Manufacturing-CW2\EXCEL\Cumulative_Operational_Cost_Over_Time_10000_1_3_1.xlsx"
df3 = pd.read_excel(file_path_3)

file_path_4 = r"C:\Users\abhin\OneDrive - University of Southampton\1 - University of Southampton\Part 4 - University of Southampton\Manufacturing\2 - CW\Q2\Manufacturing-CW2\EXCEL\Cumulative_Operational_Cost_Over_Time_5000_1_1_2_1.xlsx"
df4 = pd.read_excel(file_path_4)

file_path_5 = r"C:\Users\abhin\OneDrive - University of Southampton\1 - University of Southampton\Part 4 - University of Southampton\Manufacturing\2 - CW\Q2\Manufacturing-CW2\EXCEL\Cumulative_Operational_Cost_Over_Time_SINGLE LINE_5000_3_2.xlsx"
df5 = pd.read_excel(file_path_5)



# Plotting the graph
plt.figure(figsize=(10, 6))
plt.plot(df1['Time (Hours)'], df1['Cumulative Cost (£)'], label='2 Line Each (2 Conv) - 2500 Packs', color='b', linestyle='-', linewidth=1)
plt.plot(df2['Time (Hours)'], df2['Cumulative Cost (£)'], label='1 Line Each - 5000 Packs', color='r', linestyle='-', linewidth=1)
plt.plot(df3['Time (Hours)'], df3['Cumulative Cost (£)'], label='1 Line Lithium - 10000 Packs', color='black', linestyle='-', linewidth=1)
plt.plot(df4['Time (Hours)'], df4['Cumulative Cost (£)'], label='1 Line Each (2 Conv) - 5000 Packs', color='green', linestyle='-', linewidth=1)
plt.plot(df5['Time (Hours)'], df5['Cumulative Cost (£)'], label='1 Line for both type - 10000 Packs', color='purple', linestyle='-', linewidth=1)
plt.title('Cumulative Cost Over Time')
plt.xlabel('Time (Hours)')
plt.ylabel('Cumulative Cost (£)')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Re-importing numpy which was not defined in the previous cell and replotting the data.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

n_cell_li=30
n_cell_al=40

# Data for Lithium-ion battery environmental impact
lithium_data = {
    'Component': ['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 
                  'Container and Separator', 'Battery Management System', 'Packaging and Cooling System', 
                  '30 Cell Pack Manufacturing', 'Cradle-to-gate cumulative data', 'Pack End of Life'],
    'Energy (MJ)': [0.236, 2.30, 0.694, 0.0725, 129, 113, 49.5, 391, 8.15],
    'Global Warming (kg CO2 eq)': [0.200, 0.385, 0.030, 0.00217, 8.75, 8.59, 4.03, 39.9, 1.03],
    'Acidification (kg SO2 eq)': [0.000489, 0.000707, 0.000109, 7.25E-06, 0.0886, 0.0201, 0.0196, 0.168, 0.0304],
    'Eutrophication (kg PO4 eq)': [0.000489, 0.000236, 5.43E-05, 0.00, 0.0375, 0.0859, 0.0141, 0.161, 0.00163]
}

# Data for Aluminium-ion battery environment impact
aluminium_data = {
    'Component': ['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 
                  'Container and Separator', 'Battery Management System', 'Packaging and Cooling System', 
                  '40 Cell Pack Manufacturing', 'Cradle-to-gate cumulative data', 'Pack End of Life'],
    'Energy (MJ)': [1.48, 0.550, 0.116, 0.0651, 129, 113, 56.7, 387, 6.90],
    'Global Warming (kg CO2 eq)': [0.0909, 0.0717, 0.0102, 0.00115, 8.75, 8.59, 4.62, 28.9, 1.02],
    'Acidification (kg SO2 eq)': [0.000236, 0.000637, 5.36E-05, 6.45E-06, 0.0886, 0.0201, 0.0251, 0.171, 0.0211],
    'Eutrophication (kg PO4 eq)': [0.000236, 0.000106, 2.26E-05, 0.00, 0.0375, 0.0859, 0.0132, 0.151, 0.00142]
}

# Create pandas dataframes
lithium_df = pd.DataFrame(lithium_data)
aluminium_df = pd.DataFrame(aluminium_data)

# Calculate cell_batch_components for Lithium-ion battery for each environmental impact category
lithium_cell_batch_components_EN = n_cell_li*(lithium_df.loc[lithium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Energy (MJ)'].sum())
lithium_cell_batch_components_GW = n_cell_li*(lithium_df.loc[lithium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Global Warming (kg CO2 eq)'].sum())
lithium_cell_batch_components_AC = n_cell_li*(lithium_df.loc[lithium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Acidification (kg SO2 eq)'].sum())
lithium_cell_batch_components_EU = n_cell_li*(lithium_df.loc[lithium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Eutrophication (kg PO4 eq)'].sum())

# Calculate BMS&Cooling System for Lithium-ion battery for each environmental impact category
lithium_BMS_Cooling_System_EN = lithium_df.loc[lithium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Energy (MJ)'].sum() + lithium_cell_batch_components_EN
lithium_BMS_Cooling_System_GW = lithium_df.loc[lithium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Global Warming (kg CO2 eq)'].sum() + lithium_cell_batch_components_GW
lithium_BMS_Cooling_System_AC = lithium_df.loc[lithium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Acidification (kg SO2 eq)'].sum() + lithium_cell_batch_components_AC
lithium_BMS_Cooling_System_EU = lithium_df.loc[lithium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Eutrophication (kg PO4 eq)'].sum() + lithium_cell_batch_components_EU

# Calculate Cell manufacture for Lithium-ion battery for each environmental impact category
lithium_Cell_manufacture_EN = lithium_BMS_Cooling_System_EN + lithium_df.loc[lithium_df['Component'] == '30 Cell Pack Manufacturing', 'Energy (MJ)'].sum()
lithium_Cell_manufacture_GW = lithium_BMS_Cooling_System_GW + lithium_df.loc[lithium_df['Component'] == '30 Cell Pack Manufacturing', 'Global Warming (kg CO2 eq)'].sum()
lithium_Cell_manufacture_AC = lithium_BMS_Cooling_System_AC + lithium_df.loc[lithium_df['Component'] == '30 Cell Pack Manufacturing', 'Acidification (kg SO2 eq)'].sum()
lithium_Cell_manufacture_EU = lithium_BMS_Cooling_System_EU + lithium_df.loc[lithium_df['Component'] == '30 Cell Pack Manufacturing', 'Eutrophication (kg PO4 eq)'].sum()

# Calculate cell_batch_components for Aluminium-ion battery for each environmental impact category
aluminium_cell_batch_components_EN = n_cell_al*(aluminium_df.loc[aluminium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Energy (MJ)'].sum())
aluminium_cell_batch_components_GW = n_cell_al*(aluminium_df.loc[aluminium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Global Warming (kg CO2 eq)'].sum())
aluminium_cell_batch_components_AC = n_cell_al*(aluminium_df.loc[aluminium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Acidification (kg SO2 eq)'].sum())
aluminium_cell_batch_components_EU = n_cell_al*(aluminium_df.loc[aluminium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Eutrophication (kg PO4 eq)'].sum())

# Calculate BMS&Cooling System for Aluminium-ion battery for each environmental impact category
aluminium_BMS_Cooling_System_EN = aluminium_df.loc[aluminium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Energy (MJ)'].sum() + aluminium_cell_batch_components_EN
aluminium_BMS_Cooling_System_GW = aluminium_df.loc[aluminium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Global Warming (kg CO2 eq)'].sum() + aluminium_cell_batch_components_GW
aluminium_BMS_Cooling_System_AC = aluminium_df.loc[aluminium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Acidification (kg SO2 eq)'].sum() + aluminium_cell_batch_components_AC
aluminium_BMS_Cooling_System_EU = aluminium_df.loc[aluminium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Eutrophication (kg PO4 eq)'].sum() + aluminium_cell_batch_components_EU

# Calculate Cell manufacture for Aluminium-ion battery for each environmental impact category
aluminium_Cell_manufacture_EN = aluminium_BMS_Cooling_System_EN + aluminium_df.loc[aluminium_df['Component'] == '40 Cell Pack Manufacturing', 'Energy (MJ)'].sum()
aluminium_Cell_manufacture_GW = aluminium_BMS_Cooling_System_GW + aluminium_df.loc[aluminium_df['Component'] == '40 Cell Pack Manufacturing', 'Global Warming (kg CO2 eq)'].sum()
aluminium_Cell_manufacture_AC = aluminium_BMS_Cooling_System_AC + aluminium_df.loc[aluminium_df['Component'] == '40 Cell Pack Manufacturing', 'Acidification (kg SO2 eq)'].sum()
aluminium_Cell_manufacture_EU = aluminium_BMS_Cooling_System_EU + aluminium_df.loc[aluminium_df['Component'] == '40 Cell Pack Manufacturing', 'Eutrophication (kg PO4 eq)'].sum()


# Define the data for the Lithium battery environmental impact.
lithium_data = {
    "Process": ["Cell batch components", "BMS & cooling system", "Cell manufacture"],
    "Energy (MJ)": [lithium_cell_batch_components_EN, lithium_BMS_Cooling_System_EN, lithium_Cell_manufacture_EN],
    "Global Warming (kg CO2 eq)": [lithium_cell_batch_components_GW, lithium_BMS_Cooling_System_GW, lithium_Cell_manufacture_GW],
    "Acidification (kg SO2 eq)": [lithium_cell_batch_components_AC, lithium_BMS_Cooling_System_AC, lithium_Cell_manufacture_AC],
    "Eutrophication (kg PO4 eq)": [lithium_cell_batch_components_EU, lithium_BMS_Cooling_System_EU, lithium_Cell_manufacture_EU]
}

# Define the data for the Aluminium battery environmental impact.
aluminium_data = {
    "Process": ["Cell batch components", "BMS & cooling system", "Cell manufacture"],
    "Energy (MJ)": [aluminium_cell_batch_components_EN, aluminium_BMS_Cooling_System_EN, aluminium_Cell_manufacture_EN],
    "Global Warming (kg CO2 eq)": [aluminium_cell_batch_components_GW, aluminium_BMS_Cooling_System_GW, aluminium_Cell_manufacture_GW],
    "Acidification (kg SO2 eq)": [aluminium_cell_batch_components_AC, aluminium_BMS_Cooling_System_AC, aluminium_Cell_manufacture_AC],
    "Eutrophication (kg PO4 eq)": [aluminium_cell_batch_components_EU, aluminium_BMS_Cooling_System_EU, aluminium_Cell_manufacture_EU]
}

# Convert the data into pandas DataFrame.
lithium_df = pd.DataFrame(lithium_data)
aluminium_df = pd.DataFrame(aluminium_data)


#### OLD
# # Plotting the data for Lithium and Aluminium batteries in 4 separate graphs without stacking them.
# fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 10))
# fig.suptitle('Environmental Impact: Lithium vs Aluminium Batteries', fontsize=16)

# The width of the bars
# bar_width = 0.35

# # The x location for the groups
# ind = np.arange(len(lithium_df['Process']))

# # Plot each metric in a separate subplot
# for i, (metric, ax) in enumerate(zip(lithium_df.columns[1:], axes.flatten()), 1):
#     # Bar locations
#     lithium_bars = ind - bar_width / 2
#     aluminium_bars = ind + bar_width / 2
    
#     # Plotting the bars for lithium and aluminium
#     ax.bar(lithium_bars, lithium_df[metric], width=bar_width, label='Lithium')
#     ax.bar(aluminium_bars, aluminium_df[metric], width=bar_width, label='Aluminium')
    
#     # Adding labels and titles
#     ax.set_title(metric)
#     ax.set_xlabel('Process')
#     ax.set_ylabel(metric)
#     ax.set_xticks(ind)
#     ax.set_xticklabels(lithium_df['Process'])
#     ax.legend()

# # Adjust layout to prevent overlap
# plt.tight_layout(rect=[0, 0.03, 1, 0.95])
# plt.show()

### NEW
# Set up the matplotlib figure and axes for the 4 graphs.
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(8, 20))

# Define the title for the overall figure
fig.suptitle('Environmental Impact: Lithium vs Aluminium Batteries', fontsize=16)
# Plot each metric in a separate subplot
# Create a dictionary to store the paths to the saved images
saved_images = {}

# Plot and save each metric separately.
for i, metric in enumerate(lithium_df.columns[1:]):
    fig, ax = plt.subplots(figsize=(8, 5))
    ax.bar(lithium_df['Process'], lithium_df[metric], label='Lithium', width=bar_width)
    ax.bar(aluminium_df['Process'], aluminium_df[metric], label='Aluminium', width=bar_width)
    ax.set_title(metric)
    ax.set_xlabel('Process')
    ax.set_ylabel(metric)
    ax.legend()

    # File path for the image
    file_path = fr'C:\Users\abhin\OneDrive - University of Southampton\1 - University of Southampton\Part 4 - University of Southampton\Manufacturing\2 - CW\Q2\Manufacturing-CW2\{metric.replace(" ", "_").lower()}_comparison.png'
    fig.savefig(file_path)
    saved_images[metric] = file_path
    plt.close(fig)  # Close the plot to prevent it from displaying in the output cell

# Adjust layout to prevent overlap
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# import pandas as pd

# n_cell_li=30
# n_cell_al=40

# # Data for Lithium-ion battery environmental impact
# lithium_data = {
#     'Component': ['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 
#                   'Container and Separator', 'Battery Management System', 'Packaging and Cooling System', 
#                   '30 Cell Pack Manufacturing', 'Cradle-to-gate cumulative data', 'Pack End of Life'],
#     'Energy (MJ)': [0.236, 2.30, 0.694, 0.0725, 129, 113, 49.5, 391, 8.15],
#     'Global Warming (kg CO2 eq)': [0.200, 0.385, 0.030, 0.00217, 8.75, 8.59, 4.03, 39.9, 1.03],
#     'Acidification (kg SO2 eq)': [0.000489, 0.000707, 0.000109, 7.25E-06, 0.0886, 0.0201, 0.0196, 0.168, 0.0304],
#     'Eutrophication (kg PO4 eq)': [0.000489, 0.000236, 5.43E-05, 0.00, 0.0375, 0.0859, 0.0141, 0.161, 0.00163]
# }

# # Data for Aluminium-ion battery environment impact
# aluminium_data = {
#     'Component': ['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 
#                   'Container and Separator', 'Battery Management System', 'Packaging and Cooling System', 
#                   '40 Cell Pack Manufacturing', 'Cradle-to-gate cumulative data', 'Pack End of Life'],
#     'Energy (MJ)': [1.48, 0.550, 0.116, 0.0651, 129, 113, 56.7, 387, 6.90],
#     'Global Warming (kg CO2 eq)': [0.0909, 0.0717, 0.0102, 0.00115, 8.75, 8.59, 4.62, 28.9, 1.02],
#     'Acidification (kg SO2 eq)': [0.000236, 0.000637, 5.36E-05, 6.45E-06, 0.0886, 0.0201, 0.0251, 0.171, 0.0211],
#     'Eutrophication (kg PO4 eq)': [0.000236, 0.000106, 2.26E-05, 0.00, 0.0375, 0.0859, 0.0132, 0.151, 0.00142]
# }

# # Create pandas dataframes
# lithium_df = pd.DataFrame(lithium_data)
# aluminium_df = pd.DataFrame(aluminium_data)

# # # Display the dataframes
# # print("Lithium-ion battery environmental impact:")
# # display(lithium_df)

# # print("\nAluminium-ion battery environmental impact:")
# # display(aluminium_df)

# # Calculate cell_batch_components for Lithium-ion battery for each environmental impact category
# lithium_cell_batch_components_EN = n_cell_li*(lithium_df.loc[lithium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Energy (MJ)'].sum())
# lithium_cell_batch_components_GW = n_cell_li*(lithium_df.loc[lithium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Global Warming (kg CO2 eq)'].sum())
# lithium_cell_batch_components_AC = n_cell_li*(lithium_df.loc[lithium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Acidification (kg SO2 eq)'].sum())
# lithium_cell_batch_components_EU = n_cell_li*(lithium_df.loc[lithium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Eutrophication (kg PO4 eq)'].sum())

# # Calculate BMS&Cooling System for Lithium-ion battery for each environmental impact category
# lithium_BMS_Cooling_System_EN = lithium_df.loc[lithium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Energy (MJ)'].sum() + lithium_cell_batch_components_EN
# lithium_BMS_Cooling_System_GW = lithium_df.loc[lithium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Global Warming (kg CO2 eq)'].sum() + lithium_cell_batch_components_GW
# lithium_BMS_Cooling_System_AC = lithium_df.loc[lithium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Acidification (kg SO2 eq)'].sum() + lithium_cell_batch_components_AC
# lithium_BMS_Cooling_System_EU = lithium_df.loc[lithium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Eutrophication (kg PO4 eq)'].sum() + lithium_cell_batch_components_EU

# # Calculate Cell manufacture for Lithium-ion battery for each environmental impact category
# lithium_Cell_manufacture_EN = lithium_BMS_Cooling_System_EN + lithium_df.loc[lithium_df['Component'] == '30 Cell Pack Manufacturing', 'Energy (MJ)'].sum()
# lithium_Cell_manufacture_GW = lithium_BMS_Cooling_System_GW + lithium_df.loc[lithium_df['Component'] == '30 Cell Pack Manufacturing', 'Global Warming (kg CO2 eq)'].sum()
# lithium_Cell_manufacture_AC = lithium_BMS_Cooling_System_AC + lithium_df.loc[lithium_df['Component'] == '30 Cell Pack Manufacturing', 'Acidification (kg SO2 eq)'].sum()
# lithium_Cell_manufacture_EU = lithium_BMS_Cooling_System_EU + lithium_df.loc[lithium_df['Component'] == '30 Cell Pack Manufacturing', 'Eutrophication (kg PO4 eq)'].sum()

# # Calculate cell_batch_components for Aluminium-ion battery for each environmental impact category
# aluminium_cell_batch_components_EN = n_cell_al*(aluminium_df.loc[aluminium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Energy (MJ)'].sum())
# aluminium_cell_batch_components_GW = n_cell_al*(aluminium_df.loc[aluminium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Global Warming (kg CO2 eq)'].sum())
# aluminium_cell_batch_components_AC = n_cell_al*(aluminium_df.loc[aluminium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Acidification (kg SO2 eq)'].sum())
# aluminium_cell_batch_components_EU = n_cell_al*(aluminium_df.loc[aluminium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Eutrophication (kg PO4 eq)'].sum())

# # Calculate BMS&Cooling System for Aluminium-ion battery for each environmental impact category
# aluminium_BMS_Cooling_System_EN = aluminium_df.loc[aluminium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Energy (MJ)'].sum() + aluminium_cell_batch_components_EN
# aluminium_BMS_Cooling_System_GW = aluminium_df.loc[aluminium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Global Warming (kg CO2 eq)'].sum() + aluminium_cell_batch_components_GW
# aluminium_BMS_Cooling_System_AC = aluminium_df.loc[aluminium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Acidification (kg SO2 eq)'].sum() + aluminium_cell_batch_components_AC
# aluminium_BMS_Cooling_System_EU = aluminium_df.loc[aluminium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Eutrophication (kg PO4 eq)'].sum() + aluminium_cell_batch_components_EU

# # Calculate Cell manufacture for Aluminium-ion battery for each environmental impact category
# aluminium_Cell_manufacture_EN = aluminium_BMS_Cooling_System_EN + aluminium_df.loc[aluminium_df['Component'] == '40 Cell Pack Manufacturing', 'Energy (MJ)'].sum()
# aluminium_Cell_manufacture_GW = aluminium_BMS_Cooling_System_GW + aluminium_df.loc[aluminium_df['Component'] == '40 Cell Pack Manufacturing', 'Global Warming (kg CO2 eq)'].sum()
# aluminium_Cell_manufacture_AC = aluminium_BMS_Cooling_System_AC + aluminium_df.loc[aluminium_df['Component'] == '40 Cell Pack Manufacturing', 'Acidification (kg SO2 eq)'].sum()
# aluminium_Cell_manufacture_EU = aluminium_BMS_Cooling_System_EU + aluminium_df.loc[aluminium_df['Component'] == '40 Cell Pack Manufacturing', 'Eutrophication (kg PO4 eq)'].sum()


# # Define the data for the Lithium battery environmental impact.
# lithium_data = {
#     "Process": ["Cell batch components", "BMS & cooling system", "Cell manufacture"],
#     "Energy (MJ)": [lithium_cell_batch_components_EN, lithium_BMS_Cooling_System_EN, lithium_Cell_manufacture_EN],
#     "Global Warming (kg CO2 eq)": [lithium_cell_batch_components_GW, lithium_BMS_Cooling_System_GW, lithium_Cell_manufacture_GW],
#     "Acidification (kg SO2 eq)": [lithium_cell_batch_components_AC, lithium_BMS_Cooling_System_AC, lithium_Cell_manufacture_AC],
#     "Eutrophication (kg PO4 eq)": [lithium_cell_batch_components_EU, lithium_BMS_Cooling_System_EU, lithium_Cell_manufacture_EU]
# }

# # Define the data for the Aluminium battery environmental impact.
# aluminium_data = {
#     "Process": ["Cell batch components", "BMS & cooling system", "Cell manufacture"],
#     "Energy (MJ)": [aluminium_cell_batch_components_EN, aluminium_BMS_Cooling_System_EN, aluminium_Cell_manufacture_EN],
#     "Global Warming (kg CO2 eq)": [aluminium_cell_batch_components_GW, aluminium_BMS_Cooling_System_GW, aluminium_Cell_manufacture_GW],
#     "Acidification (kg SO2 eq)": [aluminium_cell_batch_components_AC, aluminium_BMS_Cooling_System_AC, aluminium_Cell_manufacture_AC],
#     "Eutrophication (kg PO4 eq)": [aluminium_cell_batch_components_EU, aluminium_BMS_Cooling_System_EU, aluminium_Cell_manufacture_EU]
# }

# # Convert the data into pandas DataFrame.
# lithium_df = pd.DataFrame(lithium_data)
# aluminium_df = pd.DataFrame(aluminium_data)

# # Display the dataframes
# print("Lithium-ion battery environmental impact:")
# display(lithium_df)

# print("\nAluminium-ion battery environmental impact:")
# display(aluminium_df)

# # Plotting the data for Lithium and Aluminium batteries in 4 separate graphs.
# fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 10))
# fig.suptitle('Environmental Impact: Lithium vs Aluminium Batteries', fontsize=16)

# # Plot each metric in a separate subplot.
# for i, (metric, ax) in enumerate(zip(lithium_df.columns[1:], axes.flatten()), 1):
#     ax.bar(lithium_df['Process'], lithium_df[metric], label='Lithium', width=0.4, alpha=0.6)
#     ax.bar(aluminium_df['Process'], aluminium_df[metric], label='Aluminium', width=0.4, alpha=0.6)
#     ax.set_title(metric)
#     ax.set_xlabel('Process')
#     ax.set_ylabel(metric)
#     ax.legend()

# # Adjust layout to prevent overlap
# plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
# import pandas as pd

# n_cell_li=30
# n_cell_al=40

# # Data for Lithium-ion battery environmental impact
# lithium_data = {
#     'Component': ['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 
#                   'Container and Separator', 'Battery Management System', 'Packaging and Cooling System', 
#                   '30 Cell Pack Manufacturing', 'Cradle-to-gate cumulative data', 'Pack End of Life'],
#     'Energy (MJ)': [0.236, 2.30, 0.694, 0.0725, 129, 113, 49.5, 391, 8.15],
#     'Global Warming (kg CO2 eq)': [0.200, 0.385, 0.030, 0.00217, 8.75, 8.59, 4.03, 39.9, 1.03],
#     'Acidification (kg SO2 eq)': [0.000489, 0.000707, 0.000109, 7.25E-06, 0.0886, 0.0201, 0.0196, 0.168, 0.0304],
#     'Eutrophication (kg PO4 eq)': [0.000489, 0.000236, 5.43E-05, 0.00, 0.0375, 0.0859, 0.0141, 0.161, 0.00163]
# }

# # Data for Aluminium-ion battery environment impact
# aluminium_data = {
#     'Component': ['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 
#                   'Container and Separator', 'Battery Management System', 'Packaging and Cooling System', 
#                   '40 Cell Pack Manufacturing', 'Cradle-to-gate cumulative data', 'Pack End of Life'],
#     'Energy (MJ)': [1.48, 0.550, 0.116, 0.0651, 129, 113, 56.7, 387, 6.90],
#     'Global Warming (kg CO2 eq)': [0.0909, 0.0717, 0.0102, 0.00115, 8.75, 8.59, 4.62, 28.9, 1.02],
#     'Acidification (kg SO2 eq)': [0.000236, 0.000637, 5.36E-05, 6.45E-06, 0.0886, 0.0201, 0.0251, 0.171, 0.0211],
#     'Eutrophication (kg PO4 eq)': [0.000236, 0.000106, 2.26E-05, 0.00, 0.0375, 0.0859, 0.0132, 0.151, 0.00142]
# }

# # Create pandas dataframes
# lithium_df = pd.DataFrame(lithium_data)
# aluminium_df = pd.DataFrame(aluminium_data)

# # # Display the dataframes
# # print("Lithium-ion battery environmental impact:")
# # display(lithium_df)

# # print("\nAluminium-ion battery environmental impact:")
# # display(aluminium_df)

# n_cell_al_values = [n_cell_al - 5, n_cell_al, n_cell_al + 5]
# results = {}

# # Calculate cell_batch_components for Lithium-ion battery for each environmental impact category
# lithium_cell_batch_components_EN = n_cell_li*(lithium_df.loc[lithium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Energy (MJ)'].sum())
# lithium_cell_batch_components_GW = n_cell_li*(lithium_df.loc[lithium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Global Warming (kg CO2 eq)'].sum())
# lithium_cell_batch_components_AC = n_cell_li*(lithium_df.loc[lithium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Acidification (kg SO2 eq)'].sum())
# lithium_cell_batch_components_EU = n_cell_li*(lithium_df.loc[lithium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Eutrophication (kg PO4 eq)'].sum())

# # Calculate BMS&Cooling System for Lithium-ion battery for each environmental impact category
# lithium_BMS_Cooling_System_EN = lithium_df.loc[lithium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Energy (MJ)'].sum() + lithium_cell_batch_components_EN
# lithium_BMS_Cooling_System_GW = lithium_df.loc[lithium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Global Warming (kg CO2 eq)'].sum() + lithium_cell_batch_components_GW
# lithium_BMS_Cooling_System_AC = lithium_df.loc[lithium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Acidification (kg SO2 eq)'].sum() + lithium_cell_batch_components_AC
# lithium_BMS_Cooling_System_EU = lithium_df.loc[lithium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Eutrophication (kg PO4 eq)'].sum() + lithium_cell_batch_components_EU

# # Calculate Cell manufacture for Lithium-ion battery for each environmental impact category
# lithium_Cell_manufacture_EN = lithium_BMS_Cooling_System_EN + lithium_df.loc[lithium_df['Component'] == '30 Cell Pack Manufacturing', 'Energy (MJ)'].sum()
# lithium_Cell_manufacture_GW = lithium_BMS_Cooling_System_GW + lithium_df.loc[lithium_df['Component'] == '30 Cell Pack Manufacturing', 'Global Warming (kg CO2 eq)'].sum()
# lithium_Cell_manufacture_AC = lithium_BMS_Cooling_System_AC + lithium_df.loc[lithium_df['Component'] == '30 Cell Pack Manufacturing', 'Acidification (kg SO2 eq)'].sum()
# lithium_Cell_manufacture_EU = lithium_BMS_Cooling_System_EU + lithium_df.loc[lithium_df['Component'] == '30 Cell Pack Manufacturing', 'Eutrophication (kg PO4 eq)'].sum()

# # Calculate cell_batch_components for Aluminium-ion battery for each environmental impact category
# aluminium_cell_batch_components_EN = n_cell_al*(aluminium_df.loc[aluminium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Energy (MJ)'].sum())
# aluminium_cell_batch_components_GW = n_cell_al*(aluminium_df.loc[aluminium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Global Warming (kg CO2 eq)'].sum())
# aluminium_cell_batch_components_AC = n_cell_al*(aluminium_df.loc[aluminium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Acidification (kg SO2 eq)'].sum())
# aluminium_cell_batch_components_EU = n_cell_al*(aluminium_df.loc[aluminium_df['Component'].isin(['Single Cell Anode', 'Single Cell Cathode', 'Single Cell Electrolyte', 'Container and Separator']), 'Eutrophication (kg PO4 eq)'].sum())

# # Calculate BMS&Cooling System for Aluminium-ion battery for each environmental impact category
# aluminium_BMS_Cooling_System_EN = aluminium_df.loc[aluminium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Energy (MJ)'].sum() + aluminium_cell_batch_components_EN
# aluminium_BMS_Cooling_System_GW = aluminium_df.loc[aluminium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Global Warming (kg CO2 eq)'].sum() + aluminium_cell_batch_components_GW
# aluminium_BMS_Cooling_System_AC = aluminium_df.loc[aluminium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Acidification (kg SO2 eq)'].sum() + aluminium_cell_batch_components_AC
# aluminium_BMS_Cooling_System_EU = aluminium_df.loc[aluminium_df['Component'].isin(['Battery Management System', 'Packaging and Cooling System']), 'Eutrophication (kg PO4 eq)'].sum() + aluminium_cell_batch_components_EU

# # Calculate Cell manufacture for Aluminium-ion battery for each environmental impact category
# aluminium_Cell_manufacture_EN = aluminium_BMS_Cooling_System_EN + aluminium_df.loc[aluminium_df['Component'] == '40 Cell Pack Manufacturing', 'Energy (MJ)'].sum()
# aluminium_Cell_manufacture_GW = aluminium_BMS_Cooling_System_GW + aluminium_df.loc[aluminium_df['Component'] == '40 Cell Pack Manufacturing', 'Global Warming (kg CO2 eq)'].sum()
# aluminium_Cell_manufacture_AC = aluminium_BMS_Cooling_System_AC + aluminium_df.loc[aluminium_df['Component'] == '40 Cell Pack Manufacturing', 'Acidification (kg SO2 eq)'].sum()
# aluminium_Cell_manufacture_EU = aluminium_BMS_Cooling_System_EU + aluminium_df.loc[aluminium_df['Component'] == '40 Cell Pack Manufacturing', 'Eutrophication (kg PO4 eq)'].sum()


# # Define the data for the Lithium battery environmental impact.
# lithium_data = {
#     "Process": ["Cell batch components", "BMS & cooling system", "Cell manufacture"],
#     "Energy (MJ)": [lithium_cell_batch_components_EN, lithium_BMS_Cooling_System_EN, lithium_Cell_manufacture_EN],
#     "Global Warming (kg CO2 eq)": [lithium_cell_batch_components_GW, lithium_BMS_Cooling_System_GW, lithium_Cell_manufacture_GW],
#     "Acidification (kg SO2 eq)": [lithium_cell_batch_components_AC, lithium_BMS_Cooling_System_AC, lithium_Cell_manufacture_AC],
#     "Eutrophication (kg PO4 eq)": [lithium_cell_batch_components_EU, lithium_BMS_Cooling_System_EU, lithium_Cell_manufacture_EU]
# }

# # Define the data for the Aluminium battery environmental impact.
# aluminium_data = {
#     "Process": ["Cell batch components", "BMS & cooling system", "Cell manufacture"],
#     "Energy (MJ)": [aluminium_cell_batch_components_EN, aluminium_BMS_Cooling_System_EN, aluminium_Cell_manufacture_EN],
#     "Global Warming (kg CO2 eq)": [aluminium_cell_batch_components_GW, aluminium_BMS_Cooling_System_GW, aluminium_Cell_manufacture_GW],
#     "Acidification (kg SO2 eq)": [aluminium_cell_batch_components_AC, aluminium_BMS_Cooling_System_AC, aluminium_Cell_manufacture_AC],
#     "Eutrophication (kg PO4 eq)": [aluminium_cell_batch_components_EU, aluminium_BMS_Cooling_System_EU, aluminium_Cell_manufacture_EU]
# }

# # Convert the data into pandas DataFrame.
# lithium_df = pd.DataFrame(lithium_data)
# aluminium_df = pd.DataFrame(aluminium_data)

# # Plotting the data for Lithium and Aluminium batteries in 4 separate graphs.
# fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 10))
# fig.suptitle('Environmental Impact: Lithium vs Aluminium Batteries', fontsize=16)

# # Plot each metric in a separate subplot.
# for i, (metric, ax) in enumerate(zip(lithium_df.columns[1:], axes.flatten()), 1):
#     ax.bar(lithium_df['Process'], lithium_df[metric], label='Lithium', width=0.4, alpha=0.6)
#     ax.bar(aluminium_df['Process'], aluminium_df[metric], label='Aluminium', width=0.4, alpha=0.6)
#     ax.set_title(metric)
#     ax.set_xlabel('Process')
#     ax.set_ylabel(metric)
#     ax.legend()

# # Adjust layout to prevent overlap
# plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
print(((0.168)/(0.171)-1)*100)
# Out:
# -1.7543859649122862
